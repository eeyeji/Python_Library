# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random

# %%
#y값 지정? 범위 설정
y = [2,4,6]

#선긋기
plt.plot(y)

#방금 만든 plot보여줘
plt.show()

# %%
#x값 지정, 범위 설정
x=[1,2,3]

#y값 지정 범위 설정
y = [2,4,6]

#선긋기
plt.plot(x,y)

#방금 만든 plot보여줘
plt.show()

# %%
#x값 지정, 범위 설정
x=[1,2,3]

#y값 지정 범위 설정
y = [2,4,6]

#점선을 긋기?
plt.plot(x, y, ls = '-')

#방금 만든 plot보여줘
plt.show()

# %%
#x값 지정, 범위 설정
x=[1,2,3]

#y값 지정 범위 설정
y = [2,4,6]

#점선을 긋기?
plt.plot(x, y, ls = '--')

#방금 만든 plot보여줘
plt.show()

# %%
#x값 지정, 범위 설정
x=[1,2,3]

#y값 지정 범위 설정
y = [2,4,6]

#점선을 긋기?
plt.plot(x, y, ls = '-.')

#방금 만든 plot보여줘
plt.show()

# %%
#x값 지정, 범위 설정
x=[1,2,3]

#y값 지정 범위 설정
y = [2,4,6]

#점선을 긋기?
plt.plot(x, y, ls = ':')

#방금 만든 plot보여줘
plt.show()
