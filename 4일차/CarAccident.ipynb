# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
from matplotlib import font_manager, rc  
font_name = font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family=font_name)

# %%
df1 = pd.read_csv('2014년 졸음운전 교통사고.csv', encoding = 'euc-kr')
df2 = pd.read_csv('2015년 졸음운전 교통사고.csv', encoding = 'euc-kr')
df3 = pd.read_csv('2016년 졸음운전 교통사고.csv', encoding = 'euc-kr')

# %%
data = pd.concat([df1,df2,df3])
#                      이 상태를 저장
data.set_index('구분', inplace=True)
data
# Out:
#           사고(건)  사망(명)  부상(명)
# 구분
# 2014년1월     169      7    347
# 2014년2월     145      3    268
# 2014년3월     206     12    358
# 2014년4월     182      4    360
# 2014년5월     218     17    474
# 2014년6월     233     13    457
# 2014년7월     229     14    431
# 2014년8월     222      9    447
# 2014년9월     225     15    430
# 2014년10월    210     14    392
# 2014년11월    209     10    386
# 2014년12월    178     12    329
# 2015년1월     205      8    375
# 2015년2월     175      8    375
# 2015년3월     237      4    492
# 2015년4월     227     10    486
# 2015년5월     231      9    504
# 2015년6월     207      8    401
# 2015년7월     273      7    556
# 2015년8월     268     19    534
# 2015년9월     252     10    501
# 2015년10월    214     14    475
# 2015년11월    199      3    398
# 2015년12월    213      8    428
# 2016년1월     192      5    387
# 2016년2월     174      6    328
# 2016년3월     217      7    435
# 2016년4월     216      7    419
# 2016년5월     239     13    522
# 2016년6월     200     12    362
# 2016년7월     227      9    460
# 2016년8월     230      7    490
# 2016년9월     187     13    347
# 2016년10월    183     10    367
# 2016년11월    200      5    418
# 2016년12월    168      4    364

# %% [markdown]
# ##### .copy(): 데이터 복붙

# %%
#데이터 복붙
dt=data.copy()
dt
# Out:
#           사고(건)  사망(명)  부상(명)
# 구분
# 2014년1월     169      7    347
# 2014년2월     145      3    268
# 2014년3월     206     12    358
# 2014년4월     182      4    360
# 2014년5월     218     17    474
# 2014년6월     233     13    457
# 2014년7월     229     14    431
# 2014년8월     222      9    447
# 2014년9월     225     15    430
# 2014년10월    210     14    392
# 2014년11월    209     10    386
# 2014년12월    178     12    329
# 2015년1월     205      8    375
# 2015년2월     175      8    375
# 2015년3월     237      4    492
# 2015년4월     227     10    486
# 2015년5월     231      9    504
# 2015년6월     207      8    401
# 2015년7월     273      7    556
# 2015년8월     268     19    534
# 2015년9월     252     10    501
# 2015년10월    214     14    475
# 2015년11월    199      3    398
# 2015년12월    213      8    428
# 2016년1월     192      5    387
# 2016년2월     174      6    328
# 2016년3월     217      7    435
# 2016년4월     216      7    419
# 2016년5월     239     13    522
# 2016년6월     200     12    362
# 2016년7월     227      9    460
# 2016년8월     230      7    490
# 2016년9월     187     13    347
# 2016년10월    183     10    367
# 2016년11월    200      5    418
# 2016년12월    168      4    364

# %%
#문자열로 된 날짜를 날짜로 인식하게 날짜형식으로 변형해주기
#         datetime으로 변환(바꿔주고 싶은 데이터)
dt.index=pd.to_datetime(dt.index, format='%Y년%m월')
dt.set_index([dt.index.year, dt.index.month], inplace = True)
dt.index.names=['연도', '월']
dt
# Out:
#          사고(건)  사망(명)  부상(명)
# 연도   월
# 2014 1     169      7    347
#      2     145      3    268
#      3     206     12    358
#      4     182      4    360
#      5     218     17    474
#      6     233     13    457
#      7     229     14    431
#      8     222      9    447
#      9     225     15    430
#      10    210     14    392
#      11    209     10    386
#      12    178     12    329
# 2015 1     205      8    375
#      2     175      8    375
#      3     237      4    492
#      4     227     10    486
#      5     231      9    504
#      6     207      8    401
#      7     273      7    556
#      8     268     19    534
#      9     252     10    501
#      10    214     14    475
#      11    199      3    398
#      12    213      8    428
# 2016 1     192      5    387
#      2     174      6    328
#      3     217      7    435
#      4     216      7    419
#      5     239     13    522
#      6     200     12    362
#      7     227      9    460
#      8     230      7    490
#      9     187     13    347
#      10    183     10    367
#      11    200      5    418
#      12    168      4    364

# %% [markdown]
# - 연도별 평균 사망자
# - 월별 평균 사망자
# - 힌트: 평균 사망자
# - 힌트: groupby()

# %%
y = dt.groupby(['연도']).mean()
y
# Out:
#            사고(건)      사망(명)       부상(명)
# 연도
# 2014  202.166667  10.833333  389.916667
# 2015  225.083333   9.000000  460.416667
# 2016  202.750000   8.166667  408.250000

# %%
m = dt.groupby(['월']).mean()
m
# Out:
#          사고(건)      사망(명)       부상(명)
# 월
# 1   188.666667   6.666667  369.666667
# 2   164.666667   5.666667  323.666667
# 3   220.000000   7.666667  428.333333
# 4   208.333333   7.000000  421.666667
# 5   229.333333  13.000000  500.000000
# 6   213.333333  11.000000  406.666667
# 7   243.000000  10.000000  482.333333
# 8   240.000000  11.666667  490.333333
# 9   221.333333  12.666667  426.000000
# 10  202.333333  12.666667  411.333333
# 11  202.666667   6.000000  400.666667
# 12  186.333333   8.000000  373.666667
